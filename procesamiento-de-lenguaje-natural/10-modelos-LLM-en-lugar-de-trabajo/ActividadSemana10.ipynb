# %%
# Idea de proyecto a realizar, basado en el procesamiento de lenguaje natural (NLP):

# Contexto:
# En el mundo del desarrollo de software, los ingenieros pasan una cantidad significativa de tiempo escribiendo y revisando código. Sin embargo, muchas veces el código carece de comentarios descriptivos, lo que dificulta su comprensión y mantenimiento. Además, los desarrolladores necesitan asegurarse de que su código funcione correctamente mediante pruebas unitarias, y muy frecuentemente crean "Merge Requests" (MR) para integrar sus cambios en el repositorio principal.

# Estas tareas rutinarias pueden ser tediosas y consumir mucho tiempo, lo que lleva a errores y retrasos en el desarrollo del software. Por lo tanto, existe una necesidad de una herramienta que pueda automatizar estas tareas y mejorar la eficiencia del proceso de desarrollo.

# Crear un programa que analice el código recién escrito por los desarrolladores de software y realice las siguientes tareas rutinarias:
# 1. Escribir comentarios descriptivos para cada función y clase.
# 2. Correr pruebas unitarias para verificar el correcto funcionamiento del código.
# 3. Generar un "Merge Request" (MR) con los cambios realizados. Dicho MR debe incluir:
#    - Un título descriptivo.
#    - Una descripción detallada de los cambios realizados.
#    - la tarea (ticket) asociada a la que corresponde el MR.
#    - Los test que se han realizado para verificar el correcto funcionamiento del código.

# Detalles de la entrega:
# El entregable para este proyecto debería de ser un plugin para el ambiente de desarrollo (IDE) de los ingenieros (Visual Studio Code, PyCharm, etc), que utilice el modelo Claude de Anthropic, por ser un modelo de lenguaje avanzado que puede entender el código de programación mejor que otros modelos y generar texto en lenguaje natural.
# - El programa debe ser capaz de integrarse con el sistema de control de versiones utilizado por los desarrolladores (por ejemplo, Git).
# - Debe ser capaz de analizar el código en diferentes lenguajes de programación (Python, Java, JavaScript, etc.).
# - Debe ser capaz de generar comentarios descriptivos que sigan las mejores prácticas de documentación de código.
# - Debe ser capaz de correr pruebas unitarias y generar un informe de resultados.
# - Debe ser capaz de generar un Merge Request con toda la información requerida.

# Requisitos técnicos:
# - Lenguaje de programación: Python.
# - Uso de la API de Claude Sonet 4 (claude-sonnet-4-20250514) para el procesamiento de lenguaje natural, el cual tiene una ventana de contexto de 200k tokens, lo que permite analizar grandes cantidades de código y generar comentarios detallados.
# - Uso de bibliotecas para el análisis de código y generación de comentarios (por ejemplo, `ast` para Python, `eslint` para JavaScript).
# - Modelo de alto rendimiento con capacidades de razonamiento excepcionales

# Tiempos y Costos:
# - Tiempo estimado de desarrollo: 4-6 semanas.
# - Costo estimado: 200 horas de trabajo a una tarifa de 50 USD por hora, lo que equivale a 10,000 USD.
