# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown

# %%
load_dotenv()  # Carga las variables del archivo .env
api_key = os.getenv("OPENAI_API_KEY")

if api_key:
  print("API key encontrada en los secretos", api_key)
else:
  raise ValueError("API key no encontrada en los secretos")
# Out:
# API key encontrada en los secretos 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

# %%
client = OpenAI( api_key=api_key)

response = client.responses.create(
    model="gpt-4o-mini",
    input="Explicame como funciona el invertir en la bolsa de valores",
    temperature=0.5,
)


print(response.output_text)
# Out:
# Invertir en la bolsa de valores implica comprar y vender acciones de empresas que cotizan en el mercado. Aquí tienes un resumen de cómo funciona:
#
# ### 1. **Conceptos Básicos**
#    - **Acciones**: Representan una parte de la propiedad de una empresa. Cuando compras acciones, te vuelves propietario de una pequeña parte de esa empresa.
#    - **Bolsa de Valores**: Es un mercado donde se compran y venden acciones. Ejemplos incluyen la Bolsa de Nueva York (NYSE) y el Nasdaq.
#
# ### 2. **Cómo Invertir**
#    - **Abrir una Cuenta**: Necesitas una cuenta en una correduría (broker) que te permita comprar y vender acciones.
#    - **Investigación**: Antes de invertir, investiga las empresas en las que estás interesado. Analiza sus estados financieros, perspectivas de crecimiento y el entorno del mercado.
#    - **Decidir Cuánto Invertir**: Define un presupuesto y decide cuánto estás dispuesto a invertir. Es importante no invertir dinero que no puedes permitirte perder.
#    - **Compra de Acciones**: Una vez que hayas investigado, puedes realizar una orden de compra a través de tu corredor.
#
# ### 3. **Tipos de Órdenes**
#    - **Orden de Mercado**: Compras o vendes acciones al precio actual del mercado.
#    - **Orden Limitada**: Estableces un precio específico al que deseas comprar o vender acciones. La orden se ejecutará solo si el precio alcanza ese nivel.
#
# ### 4. **Mantener y Monitorear**
#    - **Seguimiento**: Monitorea tus inversiones y el mercado en general. Puedes decidir mantener tus acciones a largo plazo o venderlas si alcanzan un precio deseado.
#    - **Diversificación**: Considera diversificar tu cartera invirtiendo en diferentes sectores o tipos de activos para reducir el riesgo.
#
# ### 5. **Riesgos y Beneficios**
#    - **Riesgos**: Las acciones pueden perder valor, y no hay garantía de ganancias. Es importante estar preparado para la volatilidad del mercado.
#    - **Beneficios**: A largo plazo, las acciones han demostrado ser una buena manera de acumular riqueza. Puedes beneficiarte de la apreciación del capital y de dividendos si la empresa los paga.
#
# ### 6. **Educación Continua**
#    - **Aprender**: La inversión en la bolsa requiere educación continua. Lee libros, toma cursos y sigue las noticias financieras para mantenerte informado.
#
# Invertir en la bolsa puede ser una forma efectiva de hacer crecer tu dinero, pero es importante hacerlo de manera informada y responsable.

# %%
Markdown(response.output_text)
# Out:
# Invertir en la bolsa de valores implica comprar y vender acciones de empresas que cotizan en el mercado. Aquí tienes un resumen de cómo funciona:
#
# ### 1. **Conceptos Básicos**
#    - **Acciones**: Representan una parte de la propiedad de una empresa. Cuando compras acciones, te vuelves propietario de una pequeña parte de esa empresa.
#    - **Bolsa de Valores**: Es un mercado donde se compran y venden acciones. Ejemplos incluyen la Bolsa de Nueva York (NYSE) y el Nasdaq.
#
# ### 2. **Cómo Invertir**
#    - **Abrir una Cuenta**: Necesitas una cuenta en una correduría (broker) que te permita comprar y vender acciones.
#    - **Investigación**: Antes de invertir, investiga las empresas en las que estás interesado. Analiza sus estados financieros, perspectivas de crecimiento y el entorno del mercado.
#    - **Decidir Cuánto Invertir**: Define un presupuesto y decide cuánto estás dispuesto a invertir. Es importante no invertir dinero que no puedes permitirte perder.
#    - **Compra de Acciones**: Una vez que hayas investigado, puedes realizar una orden de compra a través de tu corredor.
#
# ### 3. **Tipos de Órdenes**
#    - **Orden de Mercado**: Compras o vendes acciones al precio actual del mercado.
#    - **Orden Limitada**: Estableces un precio específico al que deseas comprar o vender acciones. La orden se ejecutará solo si el precio alcanza ese nivel.
#
# ### 4. **Mantener y Monitorear**
#    - **Seguimiento**: Monitorea tus inversiones y el mercado en general. Puedes decidir mantener tus acciones a largo plazo o venderlas si alcanzan un precio deseado.
#    - **Diversificación**: Considera diversificar tu cartera invirtiendo en diferentes sectores o tipos de activos para reducir el riesgo.
#
# ### 5. **Riesgos y Beneficios**
#    - **Riesgos**: Las acciones pueden perder valor, y no hay garantía de ganancias. Es importante estar preparado para la volatilidad del mercado.
#    - **Beneficios**: A largo plazo, las acciones han demostrado ser una buena manera de acumular riqueza. Puedes beneficiarte de la apreciación del capital y de dividendos si la empresa los paga.
#
# ### 6. **Educación Continua**
#    - **Aprender**: La inversión en la bolsa requiere educación continua. Lee libros, toma cursos y sigue las noticias financieras para mantenerte informado.
#
# Invertir en la bolsa puede ser una forma efectiva de hacer crecer tu dinero, pero es importante hacerlo de manera informada y responsable.
