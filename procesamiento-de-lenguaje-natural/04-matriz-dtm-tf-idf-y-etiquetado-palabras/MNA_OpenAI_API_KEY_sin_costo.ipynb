# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown

# %%
load_dotenv()  # Carga las variables del archivo .env
api_key = os.getenv("OPENAI_API_KEY")

if api_key:
  print("API key encontrada en los secretos", api_key)
else:
  raise ValueError("API key no encontrada en los secretos")
# Out:
# API key encontrada en los secretos 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

# %%
client = OpenAI( api_key=api_key)

response = client.responses.create(
    model="gpt-4o-mini",
    input="Explicame como funciona el invertir en la bolsa de valores",
    temperature=0.5,
)


print(response.output_text)
# Out:
# Invertir en la bolsa de valores implica comprar y vender acciones de empresas que cotizan en los mercados bursátiles. Aquí te explico los conceptos básicos y cómo funciona:
#
# ### 1. **¿Qué es la bolsa de valores?**
# La bolsa de valores es un mercado donde se compran y venden acciones de empresas. Las acciones representan una parte de la propiedad de una empresa. Cuando compras acciones, te conviertes en accionista y tienes derecho a una parte de las ganancias de la empresa.
#
# ### 2. **Tipos de inversiones:**
#    - **Acciones:** Comprar acciones de empresas. Puedes obtener ganancias si el valor de las acciones aumenta.
#    - **Bonos:** Invertir en deuda emitida por gobiernos o corporaciones. Recibes intereses y el capital al vencimiento.
#    - **Fondos de inversión:** Agrupan dinero de muchos inversores para comprar una variedad de activos, lo que diversifica el riesgo.
#    - **ETFs (Fondos Cotizados en Bolsa):** Fondos que se negocian como acciones y que replican un índice específico.
#
# ### 3. **Cómo empezar a invertir:**
#    - **Educación:** Aprende sobre el mercado, tipos de inversiones y análisis de acciones.
#    - **Establece un objetivo:** Define si buscas crecimiento a largo plazo, ingresos pasivos, etc.
#    - **Abre una cuenta de corretaje:** Necesitas una cuenta en una plataforma de corretaje para comprar y vender acciones.
#    - **Investiga:** Analiza las empresas en las que estás interesado, revisa sus estados financieros, desempeño histórico y perspectivas futuras.
#
# ### 4. **Análisis de inversiones:**
#    - **Análisis fundamental:** Evalúa la salud financiera de una empresa, incluyendo ingresos, ganancias, deudas y competidores.
#    - **Análisis técnico:** Examina gráficos y patrones de precios para predecir movimientos futuros del mercado.
#
# ### 5. **Riesgos:**
#    - **Volatilidad:** Los precios de las acciones pueden fluctuar significativamente.
#    - **Pérdida de capital:** Existe el riesgo de perder parte o la totalidad de tu inversión.
#    - **Factores externos:** Cambios en la economía, políticas gubernamentales y eventos globales pueden afectar el mercado.
#
# ### 6. **Estrategias de inversión:**
#    - **Inversión a largo plazo:** Comprar y mantener acciones durante años.
#    - **Trading:** Comprar y vender acciones en un corto período, buscando aprovechar las fluctuaciones del mercado.
#    - **Diversificación:** Invertir en diferentes activos para reducir el riesgo.
#
# ### 7. **Aspectos emocionales:**
#    - Mantén la calma ante la volatilidad del mercado y evita decisiones impulsivas basadas en emociones.
#
# ### 8. **Impuestos:**
#    - Infórmate sobre las implicaciones fiscales de tus inversiones, ya que las ganancias pueden estar sujetas a impuestos.
#
# ### Conclusión
# Invertir en la bolsa puede ser una forma efectiva de aumentar tu patrimonio, pero es fundamental hacerlo con conocimiento y preparación. Considera comenzar con una pequeña inversión y aumentar tu participación a medida que adquieras experiencia y confianza.

# %%
Markdown(response.output_text)
# Out:
# Invertir en la bolsa de valores implica comprar y vender acciones de empresas que cotizan en los mercados bursátiles. Aquí te explico los conceptos básicos y cómo funciona:
#
# ### 1. **¿Qué es la bolsa de valores?**
# La bolsa de valores es un mercado donde se compran y venden acciones de empresas. Las acciones representan una parte de la propiedad de una empresa. Cuando compras acciones, te conviertes en accionista y tienes derecho a una parte de las ganancias de la empresa.
#
# ### 2. **Tipos de inversiones:**
#    - **Acciones:** Comprar acciones de empresas. Puedes obtener ganancias si el valor de las acciones aumenta.
#    - **Bonos:** Invertir en deuda emitida por gobiernos o corporaciones. Recibes intereses y el capital al vencimiento.
#    - **Fondos de inversión:** Agrupan dinero de muchos inversores para comprar una variedad de activos, lo que diversifica el riesgo.
#    - **ETFs (Fondos Cotizados en Bolsa):** Fondos que se negocian como acciones y que replican un índice específico.
#
# ### 3. **Cómo empezar a invertir:**
#    - **Educación:** Aprende sobre el mercado, tipos de inversiones y análisis de acciones.
#    - **Establece un objetivo:** Define si buscas crecimiento a largo plazo, ingresos pasivos, etc.
#    - **Abre una cuenta de corretaje:** Necesitas una cuenta en una plataforma de corretaje para comprar y vender acciones.
#    - **Investiga:** Analiza las empresas en las que estás interesado, revisa sus estados financieros, desempeño histórico y perspectivas futuras.
#
# ### 4. **Análisis de inversiones:**
#    - **Análisis fundamental:** Evalúa la salud financiera de una empresa, incluyendo ingresos, ganancias, deudas y competidores.
#    - **Análisis técnico:** Examina gráficos y patrones de precios para predecir movimientos futuros del mercado.
#
# ### 5. **Riesgos:**
#    - **Volatilidad:** Los precios de las acciones pueden fluctuar significativamente.
#    - **Pérdida de capital:** Existe el riesgo de perder parte o la totalidad de tu inversión.
#    - **Factores externos:** Cambios en la economía, políticas gubernamentales y eventos globales pueden afectar el mercado.
#
# ### 6. **Estrategias de inversión:**
#    - **Inversión a largo plazo:** Comprar y mantener acciones durante años.
#    - **Trading:** Comprar y vender acciones en un corto período, buscando aprovechar las fluctuaciones del mercado.
#    - **Diversificación:** Invertir en diferentes activos para reducir el riesgo.
#
# ### 7. **Aspectos emocionales:**
#    - Mantén la calma ante la volatilidad del mercado y evita decisiones impulsivas basadas en emociones.
#
# ### 8. **Impuestos:**
#    - Infórmate sobre las implicaciones fiscales de tus inversiones, ya que las ganancias pueden estar sujetas a impuestos.
#
# ### Conclusión
# Invertir en la bolsa puede ser una forma efectiva de aumentar tu patrimonio, pero es fundamental hacerlo con conocimiento y preparación. Considera comenzar con una pequeña inversión y aumentar tu participación a medida que adquieras experiencia y confianza.
